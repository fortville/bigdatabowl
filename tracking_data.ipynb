# %% [markdown]
# # Motion Impact on Play Outcomes
# This code will try to analyse the how players move across the field based on pre snap data

# %%
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns 
import numpy as np

# %%
import os
for dirname, _, filenames in os.walk('data'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# data/.DS_Store
# data/nfl-big-data-bowl-2025/plays.csv
# data/nfl-big-data-bowl-2025/tracking_week_5.csv
# data/nfl-big-data-bowl-2025/tracking_week_4.csv
# data/nfl-big-data-bowl-2025/tracking_week_6.csv
# data/nfl-big-data-bowl-2025/tracking_week_7.csv
# data/nfl-big-data-bowl-2025/tracking_week_3.csv
# data/nfl-big-data-bowl-2025/tracking_week_2.csv
# data/nfl-big-data-bowl-2025/tracking_week_1.csv
# data/nfl-big-data-bowl-2025/players.csv
# data/nfl-big-data-bowl-2025/games.csv
# data/nfl-big-data-bowl-2025/tracking_week_9.csv
# data/nfl-big-data-bowl-2025/tracking_week_8.csv
# data/nfl-big-data-bowl-2025/player_play.csv

# %%
player_play = pd.read_csv("data/nfl-big-data-bowl-2025/player_play.csv")
games = pd.read_csv("data/nfl-big-data-bowl-2025/games.csv")
plays = pd.read_csv("data/nfl-big-data-bowl-2025/plays.csv")
players = pd.read_csv("data/nfl-big-data-bowl-2025/players.csv")

# %%
tr_week1 = pd.read_csv("data/nfl-big-data-bowl-2025/tracking_week_1.csv")

# %%
playid = 1344
gameid = 2022091200
games[games["gameId"]==gameid]
# Out:
#         gameId  season  week   gameDate gameTimeEastern homeTeamAbbr  \
# 15  2022091200    2022     1  9/12/2022        20:15:00          SEA
#
#    visitorTeamAbbr  homeFinalScore  visitorFinalScore
# 15             DEN              17                 16

# %%
tr_df = tr_week1[(tr_week1["gameId"]==gameid) & (tr_week1["playId"]==playid)]

# %%
# Filter the data for before_snap and after_snap events
before_snap_df = tr_df[tr_df['frameType'] == 'BEFORE_SNAP']
after_snap_df = tr_df[tr_df['frameType'] == 'AFTER_SNAP']


plt.figure(figsize=(12, 5.33))
sns.scatterplot(data=before_snap_df, x="x", y="y", hue="club")
plt.title('Before Snap Events')
plt.xlim(0, 120)  
plt.ylim(0, 53.3)  
plt.show()


plt.figure(figsize=(12, 5.33))
sns.scatterplot(data=after_snap_df, x="x", y="y", hue="club")
plt.title('After Snap Events')
plt.xlim(0, 120)  
plt.ylim(0, 53.3)  
plt.show()

# %% [markdown]
# Snapshot of 1 second before snap

# %%
plays
# Out:
#            gameId  playId                                    playDescription  \
# 0      2022102302    2655  (1:54) (Shotgun) J.Burrow pass short middle to...
# 1      2022091809    3698  (2:13) (Shotgun) J.Burrow pass short right to ...
# 2      2022103004    3146  (2:00) (Shotgun) D.Mills pass short right to D...
# 3      2022110610     348  (9:28) (Shotgun) P.Mahomes pass short left to ...
# 4      2022102700    2799  (2:16) (Shotgun) L.Jackson up the middle to TB...
# ...           ...     ...                                                ...
# 16119  2022110604    1051  (12:49) (Shotgun) T.Lawrence pass incomplete s...
# 16120  2022103005    3492  (12:32) (Shotgun) K.Cousins pass incomplete de...
# 16121  2022092502    2337  (9:59) (Shotgun) P.Mahomes scrambles right end...
# 16122  2022091809     719  (:45) C.Rush pass incomplete deep right to C.L...
# 16123  2022101602    3046  (15:00) Br.Hall up the middle for 34 yards, TO...
#
#        quarter  down  yardsToGo possessionTeam defensiveTeam yardlineSide  \
# 0            3     1         10            CIN           ATL          CIN
# 1            4     1         10            CIN           DAL          CIN
# 2            4     3         12            HOU           TEN          HOU
# 3            1     2         10             KC           TEN          TEN
# 4            3     2          8            BAL            TB           TB
# ...        ...   ...        ...            ...           ...          ...
# 16119        2     3          4            JAX            LV          JAX
# 16120        4     1         10            MIN           ARI          MIN
# 16121        3     1         10             KC           IND          IND
# 16122        1     1         10            DAL           CIN          CIN
# 16123        4     1         10            NYJ            GB           GB
#
#        yardlineNumber  ... yardsGained  homeTeamWinProbabilityAdded  \
# 0                  21  ...           9                     0.004634
# 1                   8  ...           4                     0.002847
# 2                  20  ...           6                     0.000205
# 3                  23  ...           4                    -0.001308
# 4                  27  ...          -1                     0.027141
# ...               ...  ...         ...                          ...
# 16119              31  ...           0                    -0.024741
# 16120              25  ...           0                    -0.026580
# 16121              13  ...          10                    -0.013790
# 16122              47  ...           0                    -0.011561
# 16123              34  ...          34                    -0.051177
#
#        visitorTeamWinProbilityAdded expectedPointsAdded  isDropback  \
# 0                         -0.004634            0.702717        True
# 1                         -0.002847           -0.240509        True
# 2                         -0.000205           -0.218480        True
# 3                          0.001308           -0.427749        True
# 4                         -0.027141           -0.638912       False
# ...                             ...                 ...         ...
# 16119                      0.024741           -1.391687        True
# 16120                      0.026580           -0.503208        True
# 16121                      0.013790            1.073898        True
# 16122                      0.011561           -0.522397        True
# 16123                      0.051177            3.155436       False
#
#        pff_runConceptPrimary  pff_runConceptSecondary  pff_runPassOption  \
# 0                        NaN                      NaN                  0
# 1                        NaN                      NaN                  0
# 2                        NaN                      NaN                  0
# 3                        NaN                      NaN                  0
# 4                        MAN              READ OPTION                  0
# ...                      ...                      ...                ...
# 16119                    NaN                      NaN                  0
# 16120                    NaN                      NaN                  0
# 16121                    NaN                      NaN                  0
# 16122              UNDEFINED                      NaN                  0
# 16123                COUNTER             MISDIRECTION                  0
#
#       pff_passCoverage pff_manZone
# 0              Cover-3        Zone
# 1             Quarters        Zone
# 2             Quarters        Zone
# 3             Quarters        Zone
# 4              Cover-1         Man
# ...                ...         ...
# 16119          Cover-2        Zone
# 16120          Cover-3        Zone
# 16121         Quarters        Zone
# 16122          Cover-3        Zone
# 16123          Cover-3        Zone
#
# [16124 rows x 50 columns]
